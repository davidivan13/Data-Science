# %% [markdown]
# <a href="https://colab.research.google.com/github/davidivan13/Data-Science/blob/main/Correlation_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library

# %%
import numpy as np #library untuk matematika
import pandas as pd #library untuk dataframe
import seaborn as sns #library untuk visualisasi
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# ## Load Data

# %%
dataset = sns.load_dataset("mpg")
dataset.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ## Membuat Scatterplot

# %%
sns.scatterplot(data = dataset,
                x = "weight",
                y = "mpg")
plt.show()

# %%
sns.scatterplot(data = dataset,
                x = "acceleration",
                y = "mpg")
plt.show()

# %%
sns.scatterplot(data = dataset,
                x = "displacement",
                y = "mpg")
plt.show()

# %%
sns.scatterplot(data = dataset,
                x = "displacement",
                y = "horsepower")
plt.show()

# %% [markdown]
# ## Membuat Korelasi Pearson

# %%
import pandas as pd
# Menggunakan pd.get_dummies untuk kolom kategorikal
dataset = pd.get_dummies(dataset, drop_first=True)
korelasi = dataset.corr()
korelasi
# Out:
#                                 mpg  cylinders  displacement  horsepower  \
# mpg                        1.000000  -0.775396     -0.804203   -0.778427
# cylinders                 -0.775396   1.000000      0.950721    0.842983
# displacement              -0.804203   0.950721      1.000000    0.897257
# horsepower                -0.778427   0.842983      0.897257    1.000000
# weight                    -0.831741   0.896017      0.932824    0.864538
# ...                             ...        ...           ...         ...
# name_vw dasher (diesel)    0.127850  -0.042977     -0.049845   -0.074288
# name_vw pickup             0.131708  -0.042977     -0.046471   -0.069026
# name_vw rabbit             0.106839  -0.060856     -0.067851   -0.058623
# name_vw rabbit c (diesel)  0.133637  -0.042977     -0.049845   -0.074288
# name_vw rabbit custom      0.053913  -0.042977     -0.050327   -0.044030
#
#                              weight  acceleration  model_year  origin_japan  \
# mpg                       -0.831741      0.420289    0.579267      0.442174
# cylinders                  0.896017     -0.505419   -0.348746     -0.396479
# displacement               0.932824     -0.543684   -0.370164     -0.433505
# horsepower                 0.864538     -0.689196   -0.416361     -0.321936
# weight                     1.000000     -0.417457   -0.306564     -0.440817
# ...                             ...           ...         ...           ...
# name_vw dasher (diesel)   -0.037706      0.148183    0.054224     -0.024976
# name_vw pickup            -0.049871      0.164583    0.081405     -0.024976
# name_vw rabbit            -0.078137     -0.028850    0.038294     -0.035366
# name_vw rabbit c (diesel) -0.052541      0.111738    0.054224     -0.024976
# name_vw rabbit custom     -0.062036     -0.028574    0.040634     -0.024976
#
#                            origin_usa  name_amc ambassador dpl  ...  \
# mpg                         -0.568192                -0.054743  ...
# cylinders                    0.604351                 0.075192  ...
# displacement                 0.651407                 0.094737  ...
# horsepower                   0.489625                 0.112519  ...
# weight                       0.598398                 0.052194  ...
# ...                               ...                      ...  ...
# name_vw dasher (diesel)     -0.064880                -0.002519  ...
# name_vw pickup              -0.064880                -0.002519  ...
# name_vw rabbit              -0.091870                -0.003567  ...
# name_vw rabbit c (diesel)   -0.064880                -0.002519  ...
# name_vw rabbit custom       -0.064880                -0.002519  ...
#
#                            name_volvo 145e (sw)  name_volvo 244dl  \
# mpg                                   -0.035455         -0.009738
# cylinders                             -0.042977         -0.042977
# displacement                          -0.034905         -0.034905
# horsepower                             0.009907         -0.008511
# weight                                -0.002221         -0.001509
# ...                                         ...               ...
# name_vw dasher (diesel)               -0.002519         -0.002519
# name_vw pickup                        -0.002519         -0.002519
# name_vw rabbit                        -0.003567         -0.003567
# name_vw rabbit c (diesel)             -0.002519         -0.002519
# name_vw rabbit custom                 -0.002519         -0.002519
#
#                            name_volvo 245  name_volvo 264gl  \
# mpg                             -0.022596         -0.041884
# cylinders                       -0.042977          0.016107
# displacement                    -0.030567         -0.014663
# horsepower                      -0.003249          0.027009
# weight                           0.010656          0.010063
# ...                                   ...               ...
# name_vw dasher (diesel)         -0.002519         -0.002519
# name_vw pickup                  -0.002519         -0.002519
# name_vw rabbit                  -0.003567         -0.003567
# name_vw rabbit c (diesel)       -0.002519         -0.002519
# name_vw rabbit custom           -0.002519         -0.002519
#
#                            name_volvo diesel  name_vw dasher (diesel)  \
# mpg                                 0.046198                 0.127850
# cylinders                           0.016107                -0.042977
# displacement                       -0.023338                -0.049845
# horsepower                         -0.037453                -0.074288
# weight                              0.011249                -0.037706
# ...                                      ...                      ...
# name_vw dasher (diesel)            -0.002519                 1.000000
# name_vw pickup                     -0.002519                -0.002519
# name_vw rabbit                     -0.003567                -0.003567
# name_vw rabbit c (diesel)          -0.002519                -0.002519
# name_vw rabbit custom              -0.002519                -0.002519
#
#                            name_vw pickup  name_vw rabbit  \
# mpg                              0.131708        0.106839
# cylinders                       -0.042977       -0.060856
# displacement                    -0.046471       -0.067851
# horsepower                      -0.069026       -0.058623
# weight                          -0.049871       -0.078137
# ...                                   ...             ...
# name_vw dasher (diesel)         -0.002519       -0.003567
# name_vw pickup                   1.000000       -0.003567
# name_vw rabbit                  -0.003567        1.000000
# name_vw rabbit c (diesel)       -0.002519       -0.003567
# name_vw rabbit custom           -0.002519       -0.003567
#
#                            name_vw rabbit c (diesel)  name_vw rabbit custom
# mpg                                         0.133637               0.053913
# cylinders                                  -0.042977              -0.042977
# displacement                               -0.049845              -0.050327
# horsepower                                 -0.074288              -0.044030
# weight                                     -0.052541              -0.062036
# ...                                              ...                    ...
# name_vw dasher (diesel)                    -0.002519              -0.002519
# name_vw pickup                             -0.002519              -0.002519
# name_vw rabbit                             -0.003567              -0.003567
# name_vw rabbit c (diesel)                   1.000000              -0.002519
# name_vw rabbit custom                      -0.002519               1.000000
#
# [313 rows x 313 columns]

# %%
sns.heatmap(korelasi, vmax = 1, vmin = -1, center = 0)
plt.show()

# %% [markdown]
# ## Uji Hipotesis

# %%
from scipy.stats import pearsonr

# %%
coef, p_val = pearsonr(dataset["mpg"], dataset["displacement"])

# %%
p_val
# Out:
# np.float64(1.655888910192966e-91)

# %%
coef
# Out:
# np.float64(-0.8042028248058979)
